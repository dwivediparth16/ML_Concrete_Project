# %% [markdown]
# ## Compressive Strength prediction model

# %%
import os

import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import metrics
# Import train_test_split function
from sklearn.model_selection import train_test_split, KFold, cross_val_score

# %%
db =  pd.read_excel('D:\Project\Concrete.xls')

# %%
db
# Out:
#       Cement (component 1)(kg in a m^3 mixture)  \
# 0                                         540.0
# 1                                         540.0
# 2                                         332.5
# 3                                         332.5
# 4                                         198.6
# ...                                         ...
# 1025                                      276.4
# 1026                                      322.2
# 1027                                      148.5
# 1028                                      159.1
# 1029                                      260.9
#
#       Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# 0                                                   0.0
# 1                                                   0.0
# 2                                                 142.5
# 3                                                 142.5
# 4                                                 132.4
# ...

# %%
db = db[['Cement (component 1)(kg in a m^3 mixture)','Water  (component 4)(kg in a m^3 mixture)','Coarse Aggregate  (component 6)(kg in a m^3 mixture)','Fine Aggregate (component 7)(kg in a m^3 mixture)', 'Age (day)','CCS']]
inputs = ['Cement (component 1)(kg in a m^3 mixture)','Water  (component 4)(kg in a m^3 mixture)','Coarse Aggregate  (component 6)(kg in a m^3 mixture)','Fine Aggregate (component 7)(kg in a m^3 mixture)', 'Age (day)']
output = ['CCS']
db
# Out:
#       Cement (component 1)(kg in a m^3 mixture)  \
# 0                                         540.0
# 1                                         540.0
# 2                                         332.5
# 3                                         332.5
# 4                                         198.6
# ...                                         ...
# 1025                                      276.4
# 1026                                      322.2
# 1027                                      148.5
# 1028                                      159.1
# 1029                                      260.9
#
#       Water  (component 4)(kg in a m^3 mixture)  \
# 0                                         162.0
# 1                                         162.0
# 2                                         228.0
# 3                                         228.0
# 4                                         192.0
# ...                                         ...
# ...

# %%
db.isnull().sum()
# Out:
# Cement (component 1)(kg in a m^3 mixture)               0
# Water  (component 4)(kg in a m^3 mixture)               0
# Coarse Aggregate  (component 6)(kg in a m^3 mixture)    0
# Fine Aggregate (component 7)(kg in a m^3 mixture)       0
# Age (day)                                               0
# CCS                                                     0
# dtype: int64

# %%
db= db.dropna()

# %%
db
# Out:
#       Cement (component 1)(kg in a m^3 mixture)  \
# 0                                         540.0
# 1                                         540.0
# 2                                         332.5
# 3                                         332.5
# 4                                         198.6
# ...                                         ...
# 1025                                      276.4
# 1026                                      322.2
# 1027                                      148.5
# 1028                                      159.1
# 1029                                      260.9
#
#       Water  (component 4)(kg in a m^3 mixture)  \
# 0                                         162.0
# 1                                         162.0
# 2                                         228.0
# 3                                         228.0
# 4                                         192.0
# ...                                         ...
# ...

# %%
X = db[inputs]
Y = db[output]

# %%
x_train, x_test, y_train, y_test = train_test_split(X,
                                                    Y,
                                                    test_size=0.2,
                                                    random_state=0
                                                   )

# %%
# Fitting the model

from sklearn.ensemble import RandomForestRegressor
  
 # create regressor object
model = RandomForestRegressor(n_estimators = 500, random_state = 42, max_depth=10)
  
# fit the regressor with x and y data
model.fit(x_train, y_train)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_8072\4067503831.py:9: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(x_train, y_train)
# RandomForestRegressor(max_depth=10, n_estimators=500, random_state=42)

# %%
# prediction
y_pred = model.predict(x_test)
#RMSE
rmse = metrics.mean_squared_error(y_test, y_pred,squared=False)
print("Root mean squared error is ", rmse)
# Out:
# Root mean squared error is  5.372825007767973

# %%
X_new=[('220','115','1000','200','28')]

# %%
y_pred=model.predict(X_new)
y_pred
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([46.39763359])
